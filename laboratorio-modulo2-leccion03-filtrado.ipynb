# %% [markdown]
# <div style="text-align: center;">
#   <img src="https://github.com/Hack-io-Data/Imagenes/blob/main/01-LogosHackio/logo_naranja@4x.png?raw=true" alt="esquema" />
# </div>

# %% [markdown]
# # Laboratorio Filtrado de Datos
#
# En este laboratorio usaremos el DataFrame creado en la lección anterior resultado de la unión de los conjuntos de datos compartidos contigo.
#
# **Instrucciones:**
#
# 1. Lee cuidadosamente el enunciado de cada ejercicio.
#
# 2. Implementa la solución en la celda de código proporcionada.

# %%
def filtro_pandas_str(dataframe,columna_a_filtrar,patron_regex):
    return dataframe[columna_a_filtrar].str.contains(patron_regex, case = False, na = True)

# %%
import pandas as pd
import numpy as np

# %%
# Carga el dataset de trabajo
df = pd.read_csv("../../labs/lab2_m2_pandas/datos/netflix_mergeado.csv",index_col=0)
df.head(5)

# %% [markdown]
# #### Ejercicio 1: ¿Cuáles son todos los títulos lanzados en 2021 que son del tipo 'Movie'?

# %%
df["release_year"].dtypes

# %%
condicion_movie = df["type"] == "Movie"
condicion_2021 = df["release_year"] == 2021

df[condicion_movie & condicion_2021]

# %% [markdown]
# #### Ejercicio 2: ¿Qué títulos tienen una duración de 90 minutos? Muestra solo las columnas de título y de duración.

# %%
df.loc[df["duration"] == "90 min",["title", "duration","director"]].head(5)

# %% [markdown]
# #### Ejercicio 3: ¿Cuáles son todos los títulos del país 'India' lanzados después de 2018?

# %%
condicion_india = df["country"] == "India"
condicionmasque2018 = df["release_year"] > 2018

df[condicion_india & condicionmasque2018][["title","country"]].reset_index()

# %% [markdown]
# #### Ejercicio 4: ¿Qué títulos tienen clasificación 'TV-14' o 'R'?

# %%
clasificacion_TV14 = df["rating"] == "TV-14"
clasificacion_R = df["rating"] == "R"

df[clasificacion_R | clasificacion_TV14]["title"]

# %% [markdown]
# #### Ejercicio 5: ¿Cuáles son los títulos dirigidos por 'Christopher Nolan' o 'Martin Scorsese'? ¿Cuántos ha dirigido cada uno de los directores?

# %%
#Filtrado para encontrar a Christopher Nolan (No está)
patron_regex = r"^c"
filtro_ = df["director"].str.contains(patron_regex, case = False, na = True)
df_filtrado = df[filtro_]
df_filtrado.sort_values(by = "director").value_counts()

# %%
lista_directores = ["Christopher Nolan", "Martin Scorsese"]

df[df["director"].isin(lista_directores)]

# %% [markdown]
# #### Ejercicio 6: ¿Qué títulos pertenecen a los países 'United States', 'United Kingdom' o 'Canada'? Dentro de estos países, ¿cuántas películas tienen más de un lenguaje?

# %%
df[df["country"] == "United Kingdom"]

# %%
lista_paises = ["United States","United Kingdom","Canada"]
df_paises = df[df["country"].isin(lista_paises)]

# %%
patron_regex = r"/"
filtro = df_paises["Language"].str.contains(patron_regex, case= False)
# Out:
# C:\Users\Víctor\AppData\Local\Temp\ipykernel_14468\54529642.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[filtro]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[283], line 3
#       1 patron_regex = r"/"
#       2 filtro = df_paises["Language"].str.contains(patron_regex, case= False)
# ----> 3 df[filtro]
#
# File c:\Users\Víctor\anaconda3\Lib\site-packages\pandas\core\frame.py:3884, in DataFrame.__getitem__(self, key)
#    3882 # Do we have a (boolean) 1d indexer?
#    3883 if com.is_bool_indexer(key):
# -> 3884     return self._getitem_bool_array(key)
#    3886 # We are left with two options: a single key, and a collection of keys,
#    3887 # We interpret tuples as collections only for non-MultiIndex
#    3888 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File c:\Users\Víctor\anaconda3\Lib\site-packages\pandas\core\frame.py:3940, in DataFrame._getitem_bool_array(self, key)
#    3934     raise ValueError(
#    3935         f"Item wrong length {len(key)} instead of {len(self.index)}."
#    3936     )
#    3938 # check_bool_indexer will throw exception if Series key cannot
#    3939 # be reindexed to match DataFrame rows
# -> 3940 key = check_bool_indexer(self.index, key)
#    3942 if key.all():
#    3943     return self.copy(deep=None)
#
# File c:\Users\Víctor\anaconda3\Lib\site-packages\pandas\core\indexing.py:2575, in check_bool_indexer(index, key)
#    2573 indexer = result.index.get_indexer_for(index)
#    2574 if -1 in indexer:
# -> 2575     raise IndexingError(
#    2576         "Unalignable boolean Series provided as "
#    2577         "indexer (index of the boolean Series and of "
#    2578         "the indexed object do not match)."
#    2579     )
#    2581 result = result.take(indexer)
#    2583 # fall through for boolean
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).

# %% [markdown]
# #### Ejercicio 7: ¿Qué títulos fueron lanzados entre 2015 y 2020, inclusive?

# %%
condicion_fechas = df["release_year"].between(2015,2020, inclusive = "both")
df[condicion_fechas].head(5)
# Out:
#    show_id   type                 title            director  \
# 0       s1  Movie  Dick Johnson Is Dead     Kirsten Johnson
# 1     s142  Movie            Extraction    Steven C. Miller
# 42   s1324  Movie          Layla Majnun          Monty Tiwa
# 49   s1345  Movie     The Last Paradiso  Rocco Ricciardulli
# 54   s1404  Movie            Double Dad        Cris D'Amato
#
#                                                  cast  \
# 0                                                 NaN
# 1   Bruce Willis, Kellan Lutz, Gina Carano, D.B. S...
# 42  Reza Rahadian, Acha Septriasa, Baim Wong, Beby...
# 49  Riccardo Scamarcio, Gaia Bermani Amaral, Valen...
# 54  Maisa Silva, Eduardo Moscovis, Marcelo Médici,...
#
#                                   country          date_added  release_year  \
# 0                           United States  September 25, 2021          2020
# 1   United States, United Kingdom, Canada   September 1, 2021          2015
# 42                              Indonesia   February 11, 2021          2020
# 49                                  Italy    February 5, 2021          2020
# 54                                 Brazil    January 15, 2021          2020
#
#    rating duration                                      listed_in  \
# 0   PG-13   90 min                                  Documentaries
# 1       R   82 min                             Action & Adventure
# 42  TV-14  119 min  Dramas, International Movies, Romantic Movies
# 49  TV-MA  107 min  Dramas, International Movies, Romantic Movies
# 54   TV-G      NaN     Children & Family Movies, Comedies, Dramas
#
#                                           description                 Title  \
# 0   As her father nears the end of his life, filmm...  Dick Johnson Is Dead
# 1   When a retired CIA agent is kidnapped, his son...            Extraction
# 42  While in Azerbaijan, Layla, an Indonesian scho...          Layla Majnun
# 49  In 1950s Italy, a passionate free spirit dream...     The Last Paradiso
# 54  While her mom is away, a teen sneaks out of th...            Double Dad
#
#              Genre           Premiere  Runtime  IMDB Score    Language
# 0      Documentary    October 2, 2020       90         7.5     English
# 1           Action     April 24, 2020      117         6.7     English
# 42  Romantic drama  February 11, 2021      119         6.4  Indonesian
# 49  Romantic drama   February 5, 2021      107         5.6     Italian
# 54    Comedy-drama   January 15, 2021      103         5.6  Portuguese

# %% [markdown]
# #### Ejercicio 8: ¿Cuáles son los títulos cuya puntuación en IMDb está entre 6.5 y 8.0 y que no sepamos cual es su duración?

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'Title', 'Genre', 'Premiere', 'Runtime', 'IMDB Score', 'Language'],
#       dtype='object')

# %%
condicion_IMDB = df["IMDB Score"].between(6.5,8.0, inclusive = "both")
condicion_duracion = df["duration"].isnull == True 
df[condicion_duracion & condicion_IMDB]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, Title, Genre, Premiere, Runtime, IMDB Score, Language]
# Index: []

# %% [markdown]
# #### Ejercicio 9: ¿Cuáles son las películas cuya duración de 90 y 150 minutos?

# %%
condicion_duracion = ["90 min","150 min"]
df[df["duration"].isin(condicion_duracion)].head(3)
# Out:
#    show_id   type                 title           director  \
# 0       s1  Movie  Dick Johnson Is Dead    Kirsten Johnson
# 33   s1172  Movie            Seaspiracy        Ali Tabrizi
# 52   s1373  Movie           June & Kopi  Noviandra Santosa
#
#                                                  cast        country  \
# 0                                                 NaN  United States
# 33                                                NaN  United States
# 52  Acha Septriasa, Ryan Delon, Makayla Rose Hilli...      Indonesia
#
#             date_added  release_year rating duration  \
# 0   September 25, 2021          2020  PG-13   90 min
# 33      March 24, 2021          2021  TV-14   90 min
# 52    January 28, 2021          2021  TV-PG   90 min
#
#                                             listed_in  \
# 0                                       Documentaries
# 33                                      Documentaries
# 52  Children & Family Movies, Dramas, Internationa...
#
#                                           description                 Title  \
# 0   As her father nears the end of his life, filmm...  Dick Johnson Is Dead
# 33  Passionate about ocean life, a filmmaker sets ...            Seaspiracy
# 52  A street dog is taken in by a young couple, an...           June & Kopi
#
#           Genre          Premiere  Runtime  IMDB Score    Language    Mins  \
# 0   Documentary   October 2, 2020       90         7.5     English  90 min
# 33  Documentary    March 24, 2021       89         8.2     English  90 min
# 52        Drama  January 28, 2021       90         6.3  Indonesian  90 min
#
#    unidad
# 0    None
# 33   None
# 52   None

# %% [markdown]
# #### Ejercicio 10: ¿Cuáles son los títulos que contienen la palabra 'Love' en su título y que sean de tipo TV Show?

# %%
patron_regex = r"love"
condicion_titulo = df["title"].str.contains(patron_regex, case = False)
condicion_tipo = df["type"] == "TV show"

df[condicion_titulo & condicion_tipo]["title"]
# Out:
# Series([], Name: title, dtype: object)

# %% [markdown]
# #### Ejercicio 11: ¿Cuáles son los títulos en los que el director tiene el apellido 'Johnson'?

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'Title', 'Genre', 'Premiere', 'Runtime', 'IMDB Score', 'Language',
#        'Mins', 'unidad'],
#       dtype='object')

# %% [markdown]
# #### Ejercicio 12: ¿Tenemos algún documental ('Documentaries') de Mike Tyson?

# %%
condicion_tipo = df["listed_in"] == "Documentaries"
patron_regex = r"mike tyson"
condicion_mike = df["cast"].str.contains(patron_regex, case=False,na=False)

df[condicion_tipo & condicion_mike][["title","listed_in","cast"]]
# Out:
# Empty DataFrame
# Columns: [title, listed_in, cast]
# Index: []

# %% [markdown]
# #### Ejercicio 13: Selecciona solo las columnas 'title', 'country' y 'release_year' del dataset.

# %%
df[['title', 'country', 'release_year']]
# Out:
#                                                 title  \
# 0                                Dick Johnson Is Dead
# 1                                          Extraction
# 2                                          Prime Time
# 3                                        Blue Miracle
# 4                                           Ghost Lab
# ..                                                ...
# 508                                               Tig
# 509                       What Happened, Miss Simone?
# 510                                  Hot Girls Wanted
# 511  The Other One: The Long Strange Trip of Bob Weir
# 512                                        My Own Man
#
#                                    country  release_year
# 0                            United States          2020
# 1    United States, United Kingdom, Canada          2015
# 2                                      NaN          2021
# 3                            United States          2021
# 4                                 Thailand          2021
# ..                                     ...           ...
# 508                          United States          2015
# 509                          United States          2015
# 510                          United States          2015
# 511                          United States          2015
# 512                          United States          2015
#
# [513 rows x 3 columns]

# %% [markdown]
# #### Ejercicio 14: Filtra las columnas que contienen la palabra 'date'.

# %%
df.filter(like = "date")
# Out:
#              date_added
# 0    September 25, 2021
# 1     September 1, 2021
# 2         June 30, 2021
# 3          May 27, 2021
# 4          May 27, 2021
# ..                  ...
# 508       July 17, 2015
# 509       June 26, 2015
# 510        May 29, 2015
# 511        May 22, 2015
# 512       March 6, 2015
#
# [513 rows x 1 columns]

# %% [markdown]
# #### Ejercicio 15: Usando `query()`, filtra todos los títulos del país 'France' con una duración de 80 minutos.

# %%
df_filtrado = df.query('country == "France" and duration == "80 min"')
df_filtrado
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, Title, Genre, Premiere, Runtime, IMDB Score, Language, Mins, unidad]
# Index: []

# %% [markdown]
# #### Ejercicio 16: Filtra los títulos que son películas ('Movie') y fueron lanzados antes de 2010.

# %%
df_filtrado_16 = df.query('type == "Movie" and "release_year" < "2010"')
df_filtrado_16
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, Title, Genre, Premiere, Runtime, IMDB Score, Language, Mins, unidad]
# Index: []

# %% [markdown]
# #### Ejercicio 17: Encuentra los 10 títulos con las puntuaciones más altas en IMDb.

# %%
df.nlargest(10,"IMDB Score").filter(["title"])
# Out:
#                                            title
# 118     David Attenborough: A Life on Our Planet
# 336                      Springsteen on Broadway
# 506  Winter on Fire: Ukraine's Fight for Freedom
# 255                       Dancing with the Birds
# 421                       Cuba and the Cameraman
# 33                                    Seaspiracy
# 114        The Three Deaths of Marisela Escobedo
# 243                                        Klaus
# 136                           My Octopus Teacher
# 142                               Rising Phoenix

# %% [markdown]
# #### Ejercicio 18: Encuentra los 5 títulos con las puntuaciones más bajas en IMDb.

# %%
df.nsmallest(10,"IMDB Score").filter(["title"])
# Out:
#                                title
# 281                  Enter the Anime
# 144                      Dark Forces
# 228                          The App
# 416                   The Open House
# 99                       Kaali Khuhi
# 246                            Drive
# 77                 Leyla Everlasting
# 181  The Last Days of American Crime
# 403                          Paradox
# 8                 Sardar Ka Grandson

# %% [markdown]
# #### Ejercicio 19: Filtra todos los títulos que no tienen un director asignado (valores nulos en la columna 'director').

# %%
# 24                   Documentary       April 7, 2021       55         6.5
# 30    Hidden-camera prank comedy      March 26, 2021       86         6.6
# 59                         Drama     January 8, 2021       96         6.1
# 62                   Documentary     January 1, 2021       53         5.9
# 70         Aftershow / Interview   December 18, 2020       31         7.0
# 77                        Comedy    December 4, 2020      112         3.7
# 126        Aftershow / Interview  September 30, 2020       28         6.8
# 142                  Documentary     August 26, 2020      106         8.1
# 146                  Documentary     August 20, 2020       16         6.4
# 194                  Documentary      April 29, 2020       97         6.4
# 201                  Documentary      April 10, 2020       92         7.2
# 210                  Documentary      March 25, 2020      108         7.7
# 234        Aftershow / Interview   November 27, 2019       23         7.4
# 273        Aftershow / Interview     August 21, 2019       10         5.2
# 278  Animation / Science Fiction     August 16, 2019       71         7.5
# 282                       Comedy      August 2, 2019      100         6.1
# 316                  Documentary      March 21, 2019       60         6.5
# 329                       Action    January 25, 2019      118         6.3
# 348              Romantic comedy   November 16, 2018      101         6.0
# 355            Mentalism special    October 19, 2018       49         7.1
# 366                  Documentary  September 13, 2018       99         7.5
# 376                       Comedy       July 20, 2018       94         5.2
#
#     Language     Mins unidad
# 24   English   55 min   None
# 30   English      NaN   None
# 59   Turkish      NaN   None
# 62   English   54 min   None
# 70   English   32 min   None
# 77   Turkish  113 min   None
# 126  English   28 min   None
# 142  English  107 min   None
# 146  English   17 min   None
# 194  English      NaN   None
# 201  English      NaN   None
# 210  English      NaN   None
# 234  English      NaN   None
# 273  English   10 min   None
# 278  English      NaN   None
# 282  English      NaN   None
# 316   French   60 min   None
# 329  English  119 min   None
# 348  English      NaN   None
# 355  English   50 min   None
# 366  English      NaN   None
# 376  English      NaN   None

# %% [markdown]
# #### Ejercicio 20: Filtra todos los títulos que tienen información completa en las columnas 'title', 'country' y 'IMDB Score'.

# %%
    f1 = df["title"].notna()
    f2 =df["country"].notna()
    f3 = df["IMDB Score"].notna()

    df[f1 & f2 & f3]
# Out:
#     show_id   type                                             title  \
# 0        s1  Movie                              Dick Johnson Is Dead
# 1      s142  Movie                                        Extraction
# 3      s835  Movie                                      Blue Miracle
# 4      s837  Movie                                         Ghost Lab
# 5      s841  Movie                       Baggio: The Divine Ponytail
# ..      ...    ...                                               ...
# 508   s5902  Movie                                               Tig
# 509   s5907  Movie                       What Happened, Miss Simone?
# 510   s5911  Movie                                  Hot Girls Wanted
# 511   s5913  Movie  The Other One: The Long Strange Trip of Bob Weir
# 512   s5917  Movie                                        My Own Man
#
#                           director  \
# 0                  Kirsten Johnson
# 1                 Steven C. Miller
# 3                   Julio Quintana
# 4              Paween Purijitpanya
# 5                Letizia Lamartire
# ..                             ...
# 508  Kristina Goolsby, Ashley York
# 509                     Liz Garbus
# 510       Jill Bauer, Ronna Gradus
# 511                    Mike Fleiss
# 512                David Sampliner
#
#                                                   cast  \
# 0                                                  NaN
# 1    Bruce Willis, Kellan Lutz, Gina Carano, D.B. S...
# 3    Jimmy Gonzales, Dennis Quaid, Anthony Gonzalez...
# 4    Thanapob Leeratanakachorn, Paris Intarakomalya...
# 5    Andrea Arcangeli, Valentina Bellè, Andrea Penn...
# ..                                                 ...
# 508                                         Tig Notaro
# 509                                                NaN
# 510                                                NaN
# 511                                           Bob Weir
# 512                                    David Sampliner
#
#                                    country          date_added  release_year  \
# 0                            United States  September 25, 2021          2020
# 1    United States, United Kingdom, Canada   September 1, 2021          2015
# 3                            United States        May 27, 2021          2021
# 4                                 Thailand        May 27, 2021          2021
# 5                                    Italy        May 26, 2021          2021
# ..                                     ...                 ...           ...
# 508                          United States       July 17, 2015          2015
# 509                          United States       June 26, 2015          2015
# 510                          United States        May 29, 2015          2015
# 511                          United States        May 22, 2015          2015
# 512                          United States       March 6, 2015          2015
#
#     rating duration                                          listed_in  \
# 0    PG-13   90 min                                      Documentaries
# 1        R   82 min                                 Action & Adventure
# 3    TV-PG      NaN  Children & Family Movies, Dramas, Faith & Spir...
# 4    TV-MA  118 min     Horror Movies, International Movies, Thrillers
# 5    TV-MA      NaN        Dramas, International Movies, Sports Movies
# ..     ...      ...                                                ...
# 508  TV-14      NaN                     Documentaries, Stand-Up Comedy
# 509  TV-14      NaN                    Documentaries, Music & Musicals
# 510  TV-MA   83 min                                      Documentaries
# 511  TV-14   84 min                    Documentaries, Music & Musicals
# 512  TV-MA   82 min                                      Documentaries
#
#                                            description  \
# 0    As her father nears the end of his life, filmm...
# 1    When a retired CIA agent is kidnapped, his son...
# 3    To save their cash-strapped orphanage, a guard...
# 4    After witnessing a haunting in their hospital,...
# 5    The story of Roberto Baggio, one of the best s...
# ..                                                 ...
# 508  Comedian Tig Notaro announced her cancer diagn...
# 509  Using never-before-heard recordings, rare arch...
# 510  This 2015 Sundance Film Festival breakout docu...
# 511  This chronicle of Bob Weir highlights his brot...
# 512  When a man discovers he will be the father to ...
#
#                                                 Title        Genre  \
# 0                                Dick Johnson Is Dead  Documentary
# 1                                          Extraction       Action
# 3                                        Blue Miracle        Drama
# 4                                           Ghost Lab       Horror
# 5                         Baggio: The Divine Ponytail       Biopic
# ..                                                ...          ...
# 508                                               Tig  Documentary
# 509                       What Happened, Miss Simone?  Documentary
# 510                                  Hot Girls Wanted  Documentary
# 511  The Other One: The Long Strange Trip of Bob Weir  Documentary
# 512                                        My Own Man  Documentary
#
#               Premiere  Runtime  IMDB Score Language     Mins unidad
# 0      October 2, 2020       90         7.5  English   90 min   None
# 1       April 24, 2020      117         6.7  English   82 min   None
# 3         May 27, 2021       95         6.7  English      NaN   None
# 4         May 26, 2021      117         5.2     Thai  118 min   None
# 5         May 26, 2021       92         6.2  Italian      NaN   None
# ..                 ...      ...         ...      ...      ...    ...
# 508      July 17, 2015       80         7.4  English      NaN   None
# 509      June 26, 2015       84         7.6  English      NaN   None
# 510       May 29, 2015       84         6.1  English   83 min   None
# 511       May 22, 2015       83         7.3  English   84 min   None
# 512  December 13, 2014       81         6.4  English   82 min   None
#
# [499 rows x 20 columns]

# %% [markdown]
# #### Ejercicio 21: Identifica si hay títulos duplicados en la columna 'title'.

# %%
dupla = df["title"].duplicated()
df[dupla]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, Title, Genre, Premiere, Runtime, IMDB Score, Language, Mins, unidad]
# Index: []
